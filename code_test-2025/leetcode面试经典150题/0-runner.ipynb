# %%
# !python 6.\ Z\ 字形变换.py
# Out:
# s=PAYPALISHIRING, numRows=3 -> PAHNAPLSIIGYIR
# s=PAYPALISHIRING, numRows=4 -> PINALSIGYAHRPI
# s=A, numRows=1 -> A
# s=AB, numRows=1 -> AB
# s=AB, numRows=2 -> AB
# s=ABC, numRows=2 -> ACB
# All tests passed

# %%
6/17
# Out:
# 0.35294117647058826

# %% [markdown]
# ![image.png](attachment:5bf8ca2a-a866-45e3-aea9-e6f56de76585.png)

# %%
/11天
/6周
